# %%
import pandas as pd

# %%
df = pd.read_excel('./AdventureWorks/FactInternetSales.xlsx')

# %%
df
# Out:
#       ProductKey  OrderDateKey  DueDateKey  ShipDateKey  CustomerKey  \
# 0            353      20121231    20130112     20130107        11345
# 1            537      20121231    20130112     20130107        11345
# 2            581      20121231    20130112     20130107        20982
# 3            490      20121231    20130112     20130107        20982
# 4            225      20121231    20130112     20130107        20982
# ...          ...           ...         ...          ...          ...
# 5622         310      20101229    20110110     20110105        21768
# 5623         346      20101229    20110110     20110105        28389
# 5624         346      20101229    20110110     20110105        25863
# 5625         336      20101229    20110110     20110105        14501
# 5626         346      20101229    20110110     20110105        11003
#
#       PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# 0                1          100                  7          SO51224
# ...

# %%
df['CustomerPONumber'].isna().sum()
# Out:
# np.int64(5627)

# %%
df.shape
# Out:
# (5627, 26)
